# %% [markdown]
# In [1]:   !pip install opencv-python-headless  Requirement already satisfied: opencv-python-headless in   /usr/local/lib/python3.12/dist-packages (4.13.0.92) Requirement already satisfied: numpy>=2 in   /usr/local/lib/python3.12/dist-packages (from opencv-python-headless)   (2.0.2)  In [11]:   from google.colab import files uploaded = files.upload()  Choose files   No file chosen     Upload widget is only available when the cell has been executed in the current browser session. Please rerun this cell to enable.  Saving output_for_speed.mp4 to output_for_speed.mp4  01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   1 / 23

# %% [markdown]
# --- End of Page 1 ---

# %% [markdown]
# In [12]:   import cv2 import numpy as np from google.colab.patches import cv2_imshow def calculate_speed(flow, scale_factor, fps):      magnitudes = np.sqrt(flow[..., 0] ** 2 + flow[..., 1] ** 2)      avg_magnitude = np.mean(magnitudes)      speed_m_per_s = avg_magnitude * scale_factor * fps      speed_km_per_h = speed_m_per_s * 3.6      return speed_km_per_h def detect_vehicles(frame, fg_mask):      contours, _ = cv2.findContours(fg_mask, cv2.RETR_TREE,   cv2.CHAIN_APPROX_SIMPLE)      vehicle_contours = []      for contour in contours:          if cv2.contourArea(contour) > 1000:              x, y, w, h = cv2.boundingRect(contour)              aspect_ratio = w / float(h)              if 1.2 > aspect_ratio > 0.3:                  vehicle_contours.append((x, y, w, h))      return vehicle_contours def draw_bounding_box(frame, vehicles, flow, scale_factor, fps):      for (x, y, w, h) in vehicles:          roi_flow = flow[y:y+h, x:x+w]          speed = calculate_speed(roi_flow, scale_factor, fps)          cv2.rectangle(frame, (x, y), (x+w, y+h), (0,255,0), 2)          cv2.putText(frame,                      f"{speed:.2f} km/h",                      (x, y-10),                      cv2.FONT_HERSHEY_SIMPLEX,                      0.5,                      (0,255,0),                      2) def main(video_path, scale_factor, fps):      cap = cv2.VideoCapture(video_path)      ret, prev_frame = cap.read()      if not ret:          print("Error reading video")  01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   2 / 23

# %% [markdown]
# --- End of Page 2 ---

# %% [markdown]
# return      prev_gray = cv2.cvtColor(prev_frame, cv2.COLOR_BGR2GRAY)      background_subtractor = cv2.createBackgroundSubtractorMOG2()      frame_count = 0      while cap.isOpened():          ret, frame = cap.read()          if not ret:              break          gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)          flow = cv2.calcOpticalFlowFarneback(prev_gray,                                              gray,                                              None,                                              0.5,                                              3,                                              15,                                              3,                                              5,                                              1.2,                                              0)          fg_mask = background_subtractor.apply(gray)          vehicles = detect_vehicles(frame, fg_mask)          draw_bounding_box(frame, vehicles, flow, scale_factor, fps)          if frame_count % 30 == 0:              cv2_imshow(frame)          frame_count += 1          prev_gray = gray.copy()      cap.release() scale_factor = 0.05 fps = 30 main(video_path, scale_factor, fps)  01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   3 / 23

# %% [markdown]
# --- End of Page 3 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   4 / 23

# %% [markdown]
# --- End of Page 4 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   5 / 23

# %% [markdown]
# --- End of Page 5 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   6 / 23

# %% [markdown]
# --- End of Page 6 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   7 / 23

# %% [markdown]
# --- End of Page 7 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   8 / 23

# %% [markdown]
# --- End of Page 8 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   9 / 23

# %% [markdown]
# --- End of Page 9 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   10 / 23

# %% [markdown]
# --- End of Page 10 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   11 / 23

# %% [markdown]
# --- End of Page 11 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   12 / 23

# %% [markdown]
# --- End of Page 12 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   13 / 23

# %% [markdown]
# --- End of Page 13 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   14 / 23

# %% [markdown]
# --- End of Page 14 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   15 / 23

# %% [markdown]
# --- End of Page 15 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   16 / 23

# %% [markdown]
# --- End of Page 16 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   17 / 23

# %% [markdown]
# --- End of Page 17 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   18 / 23

# %% [markdown]
# --- End of Page 18 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   19 / 23

# %% [markdown]
# --- End of Page 19 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   20 / 23

# %% [markdown]
# --- End of Page 20 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   21 / 23

# %% [markdown]
# --- End of Page 21 ---

# %% [markdown]
# 01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   22 / 23

# %% [markdown]
# --- End of Page 22 ---

# %% [markdown]
# Exported with  runcell  — convert notebooks to HTML or PDF anytime at runcell.dev.  01/04/2026, 12:24   Jupyter Notebook — generated with runcell  about:blank   23 / 23
